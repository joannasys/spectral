# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
# <span style="color:purple;font-size:13pt"><b>Data Dictionary</span></b>
# </div>
#
# <div style="width:900px;float:left;padding:20px;align:left;">
# Descriptors:
# <br><br>
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;}
# .tg .tg-2lp6{font-weight:bold;background-color:#bbdaff;vertical-align:top}
# .tg .tg-amwm{font-weight:bold;text-align:center;vertical-align:top}
# .tg .tg-36xf{font-weight:bold;background-color:#bbdaff}
# .tg .tg-yw4l{vertical-align:top}
# .tg .tg-yw42{vertical-align:top;color:blue}
# </style>
# <table class="tg">
#
#   <tr>
#     <th class="tg-36xf">Feature Name</th>
#     <th class="tg-2lp6">Description</th>
#     <th class="tg-2lp6">Metrics</th>
#   </tr>
#
# <tr>
#     <td class="tg-yw4l">RecordID</td>
#     <td class="tg-yw4l">A unique integer for each ICU stay </td>
#     <td class="tg-yw4l">Integer</td>
# </tr>
# <tr>
#     <td class="tg-yw4l">Age</td>
#     <td class="tg-yw4l">Age</td>
#     <td class="tg-yw4l">(years)</td>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">Height</td>
#     <td class="tg-yw4l">Height</td>
#     <td class="tg-yw4l">(cm)</td>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">ICUtype</td>
#     <td class="tg-yw4l">ICU Type</td>
#     <td class="tg-yw4l">(1: Coronary Care Unit, 2: Cardiac Surgery Recovery Unit, <br>3: Medical ICU, or 4: Surgical ICU)</td>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">Gender</td>
#     <td class="tg-yw4l">Gender</td>
#     <td class="tg-yw4l">(0: female, or 1: male)</td>
# </tr>
#
# </table>
# <br><br>
# These 37 variables may be observed once, more than once, or not at all in some cases:
# <br><br>
#
# <table class="tg">
# <tr>
#     <th class="tg-36xf">Feature Name</th>
#     <th class="tg-2lp6">Description</th>
#     <th class="tg-2lp6">Metrics</th>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">Albumin</td>
#     <td class="tg-yw4l">Albumin </td>
#     <td class="tg-yw4l">(g/dL)</td>
# </tr>
# <tr>
#     <td class="tg-yw4l">ALP</td>
#     <td class="tg-yw4l">Alkaline phosphatase</td>
#     <td class="tg-yw4l">(IU/L)</td>
# </tr>
# <tr>
# <td class="tg-yw4l">ALT</td>
# <td class="tg-yw4l">Alanine transaminase</td>
# <td class="tg-yw4l">(IU/L)</td>
# </tr>
# <tr>
# <td class="tg-yw4l">AST</td>
# <td class="tg-yw4l">Aspartate transaminase</td>
# <td class="tg-yw4l">(IU/L)</td>
# </tr>
# <tr>
# <td class="tg-yw4l">Bilirubin</td>
# <td class="tg-yw4l">Bilirubin</td>
# <td class="tg-yw4l">(mg/dL)</td>
# </tr>
# <tr>
# <td class="tg-yw4l">BUN</td>
# <td class="tg-yw4l">Blood urea nitrogen</td>
# <td class="tg-yw4l">(mg/dL)</td>
# </tr>
# <tr>
# <td class="tg-yw4l">Cholesterol</td>
# <td class="tg-yw4l">Cholesterol</td>
# <td class="tg-yw4l">(mg/dL)</td>
# </tr>
# <tr>
# <td class="tg-yw4l">Creatinine</td>
# <td class="tg-yw4l">Serum creatinine</td>
# <td class="tg-yw4l">(mg/dL)</td>
# </tr>
#
# <tr>
# <td class="tg-yw4l">DiasABP <td class="tg-yw4l">Invasive diastolic arterial blood pressure <td class="tg-yw4l">(mmHg)</tr>
#
# <tr><td class="tg-yw4l">FiO2 <td class="tg-yw4l">Fractional inspired O2 <td class="tg-yw4l">(0-1)</tr>
# <tr><td class="tg-yw4l">GCS <td class="tg-yw4l">Glasgow Coma Score <td class="tg-yw4l">(3-15)</tr>
# <tr><td class="tg-yw4l">Glucose <td class="tg-yw4l">Serum glucose <td class="tg-yw4l">(mg/dL)</tr>
# <tr><td class="tg-yw4l">HCO3 <td class="tg-yw4l">Serum bicarbonate <td class="tg-yw4l">(mmol/L)</tr>
# <tr><td class="tg-yw4l">HCT <td class="tg-yw4l">Hematocrit <td class="tg-yw4l">(%)</tr>
# <tr><td class="tg-yw4l">HR <td class="tg-yw4l">Heart rate <td class="tg-yw4l">(bpm)</tr>
# <tr><td class="tg-yw4l">K <td class="tg-yw4l">Serum potassium <td class="tg-yw4l">(mEq/L)</tr>
# <tr><td class="tg-yw4l">Lactate <td class="tg-yw4l">Lactate<td class="tg-yw4l">(mmol/L)</tr>
# <tr><td class="tg-yw4l">Mg <td class="tg-yw4l">Serum magnesium <td class="tg-yw4l">(mmol/L)</tr>
# <tr><td class="tg-yw4l">MAP <td class="tg-yw4l">Invasive mean arterial blood pressure <td class="tg-yw4l">(mmHg)</tr>
# <tr><td class="tg-yw4l">MechVent <td class="tg-yw4l">Mechanical ventilation respiration <td class="tg-yw4l">(0:false, or 1:true)</tr>
# <tr><td class="tg-yw4l">Na <td class="tg-yw4l">Serum sodium <td class="tg-yw4l">(mEq/L)</tr>
# <tr><td class="tg-yw4l">NIDiasABP <td class="tg-yw4l">Non-invasive diastolic arterial blood pressure <td class="tg-yw4l">(mmHg)</tr>
# <tr><td class="tg-yw4l">NIMAP <td class="tg-yw4l">Non-invasive mean arterial blood pressure <td class="tg-yw4l">(mmHg)</tr>
# <tr><td class="tg-yw4l">NISysABP <td class="tg-yw4l">Non-invasive systolic arterial blood pressure <td class="tg-yw4l">(mmHg)</tr>
# <tr><td class="tg-yw4l">PaCO2 <td class="tg-yw4l">partial pressure of arterial CO2 <td class="tg-yw4l">(mmHg)</tr>
# <tr><td class="tg-yw4l">PaO2 <td class="tg-yw4l">Partial pressure of arterial O2 <td class="tg-yw4l">(mmHg)</tr>
# <tr><td class="tg-yw4l">pH <td class="tg-yw4l">Arterial pH <td class="tg-yw4l">(0-14)</tr>
# <tr><td class="tg-yw4l">Platelets <td class="tg-yw4l">Platelets<td class="tg-yw4l">(cells/nL)</tr>
# <tr><td class="tg-yw4l">RespRate <td class="tg-yw4l">Respiration rate <td class="tg-yw4l">(bpm)</tr>
# <tr><td class="tg-yw4l">SaO2 <td class="tg-yw4l">O2 saturation in hemoglobin <td class="tg-yw4l">(%)</tr>
# <tr><td class="tg-yw4l">SysABP <td class="tg-yw4l">Invasive systolic arterial blood pressure <td class="tg-yw4l">(mmHg)</tr>
# <tr><td class="tg-yw4l">Temp <td class="tg-yw4l">Temperature <td class="tg-yw4l">(°C)</tr>
# <tr><td class="tg-yw4l">TropI <td class="tg-yw4l">Troponin-I <td class="tg-yw4l">(μg/L)</tr>
# <tr><td class="tg-yw4l">TropT <td class="tg-yw4l">Troponin-T <td class="tg-yw4l">(μg/L)</tr>
# <tr><td class="tg-yw4l">Urine <td class="tg-yw4l">Urine output <td class="tg-yw4l">(mL)</tr>
# <tr><td class="tg-yw4l">WBC <td class="tg-yw4l">White blood cell count <td class="tg-yw4l">(cells/nL)</tr>
# <tr><td class="tg-yw4l">Weight <td class="tg-yw4l">Weight<td class="tg-yw4l">(kg)</tr></table>
#
# <br><br>
# Outcomes-Related Descriptors:
#
# <table class="tg">
# <tr>
#     <th class="tg-36xf">Outcomes</th>
#     <th class="tg-2lp6">Description</th>
#     <th class="tg-2lp6">Metrics</th>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">SAPS-I score</td>
#     <td class="tg-yw4l">(Le Gall et al., 1984) </td>
#     <td class="tg-yw4l">between 0 to 163</td>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">SOFA score</td>
#     <td class="tg-yw4l">(Ferreira et al., 2001) </td>
#     <td class="tg-yw4l">between 0 to 4</td>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">Length of stay</td>
#     <td class="tg-yw4l">Length of stay </td>
#     <td class="tg-yw4l">(days)</td>
# </tr>
#
# <tr>
#     <td class="tg-yw4l">Survival</td>
#     <td class="tg-yw4l">Survival</td>
#     <td class="tg-yw4l">(days)</td>
# </tr>
#
# <tr>
#     <td class="tg-yw42"><b>In-hospital death</b></td>
#     <td class="tg-yw42"><b>Target Variable</b></td>
#     <td class="tg-yw42"><b>(0: survivor, or 1: died in-hospital)</b></td>
# </tr></table>

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <span style="color:purple;font-size:13pt"><b>Import Packages</span></b>
#
# </div>

# %%
# Import packages

# Base
import pandas as pd
import numpy as np

# Visualisation
import seaborn as sns
import matplotlib.pyplot as plt


# Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline

# Processing
from sklearn.preprocessing import RobustScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import Normalizer
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler

# Modeling
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegressionCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
import keras.callbacks

from sklearn.model_selection import GridSearchCV


# Imbalance
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE

# Evaluation
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report


pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows',200)


sns.set_style('whitegrid')
sns.set(rc={"figure.figsize": (15, 8)})

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# Simple cleaning on csv file

mortality = pd.read_pickle('mortality_filled_median_3000.pickle')
#mortality.drop(['Unnamed: 0'],axis=1,inplace=True)
#mortality#.set_index('recordid',inplace=True)

# %%
X = mortality.drop(['in-hospital_death','sofa'],axis=1)   # identify predictors

# %%
y = mortality['in-hospital_death']

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <span style="color:purple;font-size:13pt"><b>Imbalanced Data</span></b>
# <b></b>
#
# </div>

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = '1','0'
sizes = [y[y == 1].count(),y[y == 0].count()]
colors = ['gold','lightcoral']
explode = (0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.legend()
plt.title('Imbalanced Class')

plt.show()

# %% [markdown]
# In-hospital mortality will be our target in this project - 1 being in-hospital death while 0 being survival. The graph below shows the distribution of the two classes. There are only 15.0% of in-hospital mortality (positives) in the dataset. In such cases, using accuracy as a metric will be misleading and unreliable. (Think about it. Even without any algorithm, we will achieve an accuracy of 85.0%!)

# %% [markdown]
# Hence, instead of accuracy, precision and recall scores will be a more meaningful metric to evaluate our model performance. We will be using the same scoring as the PhysioNet 2012 challenge - the minimum of precision score and recall score. We define true positives (TP), false positives (FP), false negatives (FN), and true negatives (TN) as below:

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;}
# .tg .tg-yw4l{vertical-align:top}
# </style>
# <table class="tg">
#   <tr>
#     <th class="tg-031e"></th>
#     <th class="tg-031e"></th>
#     <th class="tg-031e" colspan="2">Observed</th>
#   </tr>
#   <tr>
#     <td class="tg-031e"></td>
#     <td class="tg-031e"></td>
#     <td class="tg-031e">Death</td>
#     <td class="tg-yw4l">Survivor</td>
#   </tr>
#   <tr>
#     <td class="tg-031e">Predicted</td>
#     <td class="tg-031e">Death</td>
#     <td class="tg-031e">TP</td>
#     <td class="tg-yw4l">FP</td>
#   </tr>
#   <tr>
#     <td class="tg-031e"></td>
#     <td class="tg-031e">Survivor</td>
#     <td class="tg-031e">FN</td>
#     <td class="tg-yw4l">TN</td>
#   </tr>
# </table>

# %% [markdown]
# $$Recall = \frac{TP}{(TP + FN)}$$$   $$$Precision = \frac{TP}{(TP + FP)}$$

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <span style="color:purple;font-size:13pt"><b>EDA</span></b>
# <br><br>
# <b>Step 1: Correlation Matrix</b>
# <br>Visualise correlation between features
# <br><br>
# <b>Step 2: Boxplot</b>
# <br>Visualise for outliers
# </div>

# %%
# Correlation Matrix

sns.set(rc={"figure.figsize": (15, 10)})

corr = mortality.corr()
cmap = sns.color_palette("RdBu_r", 7)

sns.heatmap(corr,cmap=cmap)

# %% [markdown]
# In the above correlation matrix, we can see that there are more lighter blue than red. A lighter colour indicates that there is little correlation between the features. The distinct horizontal lines are due to high correlations between the mean, minimum, maximum, first and last of the same variable.
# <br><br>
# We can observed that there are vertical and horizontal light blue lines. That is because the variable 'MechVent' is a binary variable. A further exploration tells us that there is 0 variance in this variable (all values in this column is 1!) This variable will not be useful in our predictions. We will drop these columns.

# %%
mortality['mean_mechvent'].value_counts()
# Out:
# 1.0    3281
# Name: mean_mechvent, dtype: int64

# %%
mortality.drop(['first_mechvent','last_mechvent','mean_mechvent','min_mechvent','max_mechvent'],axis=1,inplace=True)

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <b>Test for normality</b>
#
# </div>

# %%
from scipy.stats import normaltest

# %% [markdown]
# null hypothesis: sample comes from a normal distribution.

# %%
pvalues = []

for column in mortality.drop('in-hospital_death',axis=1).columns:
    
    p = normaltest(mortality[mortality['in-hospital_death'] == 0.0][column])[1]
    pvalues.append(p)

# %%
pd.DataFrame(pvalues,columns=['p-values'],index=mortality.drop('in-hospital_death',axis=1).columns).sort_values('p-values')
# Out:
#                        p-values
# max_wbc            0.000000e+00
# last_pao2          0.000000e+00
# mean_bun           0.000000e+00
# mean_bilirubin     0.000000e+00
# mean_sao2          0.000000e+00
# mean_ast           0.000000e+00
# mean_temp          0.000000e+00
# mean_wbc           0.000000e+00
# last_map           0.000000e+00
# last_lactate       0.000000e+00
# min_alp            0.000000e+00
# min_alt            0.000000e+00
# min_ast            0.000000e+00
# max_ph             0.000000e+00
# min_bilirubin      0.000000e+00
# min_bun            0.000000e+00
# last_ph            0.000000e+00
# last_bun           0.000000e+00
# mean_creatinine    0.000000e+00
# last_sao2          0.000000e+00
# mean_map           0.000000e+00
# max_glucose        0.000000e+00
# max_lactate        0.000000e+00
# mean_mg            0.000000e+00
# max_diasabp        0.000000e+00
# max_creatinine     0.000000e+00
# max_bun            0.000000e+00
# max_bilirubin      0.000000e+00
# ...

# %%
pvalues = []

for column in mortality.drop('in-hospital_death',axis=1).columns:
    
    p = normaltest(mortality[mortality['in-hospital_death'] == 1.0][column])[1]
    pvalues.append(p)

# %%
pd.DataFrame(pvalues,columns=['p-values'],index=mortality.drop('in-hospital_death',axis=1).columns).sort_values('p-values')
# Out:
#                        p-values
# first_ph          7.316755e-264
# max_ph            8.849698e-262
# mean_ph           1.728211e-248
# sum_urine         1.218048e-236
# first_temp        8.738556e-227
# min_ph            4.148796e-217
# min_ast           4.153483e-210
# first_ast         7.463804e-187
# first_alt         4.881687e-175
# last_alp          1.178989e-162
# min_temp          2.668128e-159
# max_sao2          1.526172e-155
# max_alp           3.058482e-154
# last_ast          4.225109e-152
# mean_sao2         2.530198e-151
# mean_ast          3.329652e-151
# last_wbc          7.366847e-150
# first_wbc         1.170028e-147
# min_alt           3.947042e-143
# last_alt          5.146914e-139
# max_wbc           3.885434e-138
# max_ast           9.288040e-137
# first_sao2        2.135218e-136
# last_sao2         3.031845e-136
# max_alt           5.491537e-136
# first_alp         3.773586e-130
# min_alp           1.088873e-124
# mean_alp          2.588928e-124
# ...

# %%
pvalues = []

for column in mortality.drop('in-hospital_death',axis=1).columns:
    
    p = normaltest(mortality[column])[1]
    pvalues.append(p)

# %%
pd.DataFrame(pvalues,columns=['p-values'],index=mortality.drop('in-hospital_death',axis=1).columns).sort_values('p-values')
# Out:
#                        p-values
# min_alt            0.000000e+00
# max_ast            0.000000e+00
# max_alt            0.000000e+00
# max_alp            0.000000e+00
# mean_temp          0.000000e+00
# last_wbc           0.000000e+00
# last_temp          0.000000e+00
# last_sao2          0.000000e+00
# last_ph            0.000000e+00
# last_pao2          0.000000e+00
# mean_wbc           0.000000e+00
# min_alp            0.000000e+00
# mean_bun           0.000000e+00
# min_ast            0.000000e+00
# last_map           0.000000e+00
# last_lactate       0.000000e+00
# min_bilirubin      0.000000e+00
# min_bun            0.000000e+00
# max_bilirubin      0.000000e+00
# min_creatinine     0.000000e+00
# max_bun            0.000000e+00
# max_diasabp        0.000000e+00
# mean_bilirubin     0.000000e+00
# mean_ast           0.000000e+00
# mean_alt           0.000000e+00
# mean_alp           0.000000e+00
# max_wbc            0.000000e+00
# max_sao2           0.000000e+00
# ...

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <b>Check for outliers</b>
#
# </div>

# %%
mortality.describe()
# Out:
#        first_albumin    first_alp    first_alt     first_ast  first_bilirubin  \
# count    3281.000000  3281.000000  3281.000000   3281.000000      3281.000000
# mean        2.968851    92.858884   130.180585    197.101646         1.452255
# std         0.566335    90.469034   540.264032    826.100299         3.225585
# min         1.100000    12.000000     1.000000      5.000000         0.100000
# 25%         2.600000    56.000000    19.000000     29.000000         0.500000
# 50%         2.950000    74.000000    30.000000     47.000000         0.700000
# 75%         3.350000    99.000000    58.000000     85.000000         1.200000
# max         5.300000  1752.000000  9890.000000  16040.000000        45.500000
#
#          first_bun  first_creatinine  first_diasabp   first_fio2    first_gcs  \
# count  3281.000000       3281.000000    3281.000000  3281.000000  3281.000000
# mean     25.758915          1.365254      58.549070     0.793051     9.309357
# ...

# %% [markdown]
# There are clearly some distinct values that doesn't look right. Let's investigate further into it.

# %% [markdown]
# <b>PH</b>
# <br>PH level is between 0 - 14. There are some records that are off the charts, probably due to human error or different metrics. We will be imputing them with the median of the same age, icutype and gender.

# %%
filled_median_group = pd.read_pickle('filled_median_group_3000.pickle')

# %%
# replace ph levels with median of same age, icutype and gender

mask = ['age','gender','icutype']
fill_col = ['first_ph','last_ph','mean_ph','min_ph','max_ph']

new_rows = []

for ind, row in mortality.iterrows():
    
    age = row['age']
    gender = row['gender']
    icutype = row['icutype']
    
    median_row = filled_median_group.loc[(filled_median_group.index.get_level_values('age')==age)&\
                                    (filled_median_group.index.get_level_values('icutype')==icutype)&\
                                (filled_median_group.index.get_level_values('gender')==gender)]
    
    new_row = []
    
    for col in fill_col:
        
        new_val = median_row[col].get_values()
        
        for val in new_val:
        
            if row[col] > 14 or row[col] < 5:

                 new_row.append(val)

            else:
                new_row.append(row[col])
    
    new_rows.append(new_row)

mortality_filled_out = pd.DataFrame(data=new_rows,columns = mortality[fill_col].columns,index=mortality[fill_col].index)
mortality_filled_out.head()
# Out:
#           first_ph  last_ph   mean_ph  min_ph  max_ph
# recordid
# 132540.0      7.45    7.370  7.395000    7.34    7.45
# 132541.0      7.51    7.470  7.495000    7.47    7.51
# 132543.0      7.32    7.385  7.336500    7.29    7.40
# 132547.0      7.29    7.460  7.405714    7.29    7.46
# 132551.0      7.40    7.370  7.274000    7.11    7.40

# %%
mortality[fill_col] = mortality_filled_out[fill_col] # Impute pH > 14 with median of common age, icutype and gender

# %%
mortality.drop(138889,inplace=True)

# %% [markdown]
# <b>Temperature</b>
# <br>Normal human temperature ranges from 34 degrees to 42 degrees. There are some records that are off the charts, (negative temperature) probably due to human errorin recording. We will be imputing them with the median of the same age, icutype and gender.

# %%
# replace temperature with median of same age, icutype and gender

mask = ['age','gender','icutype']
fill_col = ['first_temp','last_temp','mean_temp','min_temp','max_temp']

new_rows = []

for ind, row in mortality.iterrows():
    
    age = row['age']
    gender = row['gender']
    icutype = row['icutype']
    
    median_row = filled_median_group.loc[(filled_median_group.index.get_level_values('age')==age)&\
                                    (filled_median_group.index.get_level_values('icutype')==icutype)&\
                                (filled_median_group.index.get_level_values('gender')==gender)]
    
    new_row = []
    
    for col in fill_col:
        
        new_val = median_row[col].get_values()
        
        for val in new_val:
        
            if row[col] < 30:

                 new_row.append(val)

            else:
                new_row.append(row[col])
    
    new_rows.append(new_row)

mortality_filled_out = pd.DataFrame(data=new_rows,columns = mortality[fill_col].columns,index=mortality[fill_col].index)
mortality_filled_out.head()
# Out:
#           first_temp  last_temp  mean_temp  min_temp  max_temp
# recordid
# 132540.0        35.2       37.1  36.939130      34.5      37.9
# 132541.0        37.8       37.2  37.800000      36.7      39.0
# 132543.0        36.3       37.0  36.223077      35.1      37.0
# 132547.0        35.8       37.3  37.577778      35.8      38.2
# 132551.0        38.0       36.6  37.005556      35.6      38.0

# %%
mortality[fill_col] = mortality_filled_out[fill_col] # Impute temperature < 30 with median of common age, icutype and gender

# %%
mortality.loc[136692,'first_temp'] = mortality.loc[136692,'last_temp']
mortality.loc[136692,'min_temp'] = mortality.loc[136692,'last_temp']
mortality.loc[136692,'mean_temp'] = mortality.loc[136692,'last_temp']

# %%
mortality.loc[139441,'first_temp'] = mortality.loc[139441,'last_temp']
mortality.loc[139441,'min_temp'] = mortality.loc[139441,'last_temp']
mortality.loc[139441,'mean_temp'] = mortality.loc[139441,'last_temp']

# %%
mortality[mortality['min_temp'] < 30]['min_temp']
# Out:
# recordid
# 134110.0     2.8
# 140343.0    17.8
# 140884.0    18.6
# Name: min_temp, dtype: float64

# %%
mortality.loc[134110,'min_temp'] = mortality.loc[134110,'first_temp']
mortality.loc[140343,'min_temp'] = mortality.loc[140343,'first_temp']
mortality.loc[140884,'min_temp'] = mortality.loc[140884,'first_temp']

# %% [markdown]
# <b>Urine output</b><br>
# Urine output seems to be the one that has the highest outlier. A higher urine output level could be due to recording error. We will be imputing urine output > 20000ml with the median of the same age, icutype and gender  <br><br>

# %%
# replace urine output levels with median of same age, icutype and gender

mask = ['age','gender','icutype']
fill_col = ['sum_urine']

new_rows = []

for ind, row in mortality.iterrows():
    
    age = row['age']
    gender = row['gender']
    icutype = row['icutype']
    
    median_row = filled_median_group.loc[(filled_median_group.index.get_level_values('age')==age)&\
                                    (filled_median_group.index.get_level_values('icutype')==icutype)&\
                                (filled_median_group.index.get_level_values('gender')==gender)]
    
    new_row = []
    
    for col in fill_col:
        
        new_val = median_row[col].get_values()
        
        for val in new_val:
        
            if row[col] > 20000:

                 new_row.append(val)

            else:
                new_row.append(row[col])
    
    new_rows.append(new_row)

mortality_filled_out = pd.DataFrame(data=new_rows,columns = mortality[fill_col].columns,index=mortality[fill_col].index)
mortality_filled_out.head()
# Out:
#           sum_urine
# recordid
# 132540.0     6214.0
# 132541.0     5123.0
# 132543.0     3275.0
# 132547.0     4090.0
# 132551.0     1621.0

# %%
mortality[fill_col] = mortality_filled_out[fill_col] # Impute urine output > 20000 with median of common age, icutype and gender

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <b>Feature Engineering: </b> PaO2 / FiO2
#
# </div>

# %% [markdown]
# PaO2/FiO2 ratio is the ratio of arterial oxygen partial pressure to fractional inspired oxygen aka the Carrico index and the PF ratio. It has been used in the SAPS-| and SOFA scoring for critical assessment. Since we have PaO2 and FiO2 information, we are able to engineer the PF ratio as an additional feature.

# %%
mortality['pao2/fio2'] = mortality['mean_pao2'] / mortality['mean_fio2']

# %%
drop_col = mortality.columns[mortality.columns.str.contains('\w+_pao2|\w+_fio2')]
mortality.drop(drop_col,axis=1,inplace=True)

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <span style="color:purple;font-size:13pt"><b>Feature Preprocessing</span></b>
# <br><br>
# <b>Step 1: Preprocess</b>
# <br>
# Get dummy variables for categorical features
# <br>
# Scale numerical features with Robust Scaler
# <br>
# (Scaled with median and the interquartile range so that outliers can be taken into account)
# <br><br>
# <b>Step 2: Variance Inflation Factor</b>
# <br>Drop columns that are multi-colinear with each other
# </div>

# %%
class Categorical_Extractor(BaseEstimator, TransformerMixin):
    """Get dummy variables for categorical features"""
    
    def __init__(self):
        pass

    def get_dummy_(self,df):
        
        icu_dummy = pd.get_dummies(df['icutype'],drop_first=True)
        df = pd.concat((df['gender'],icu_dummy),axis=1)
        
        return df.values.reshape(-1, 4)
    
    def transform(self, X, *args):
        
        X = self.get_dummy_(X)
        
        return X


    def fit(self, X, *args):
        return self

# %%
class Numerical_Extractor(BaseEstimator, TransformerMixin):
    """Use RobustScaler on numerical features"""
    
    def __init__(self):
        pass

    def robust_scale_(self,df,threshold=10):
        
        num_col = []
        for col, num in df.nunique().iteritems():
            if num > threshold:
                num_col.append(col)
                
        df = df[num_col]
        
        rscaler = RobustScaler()
        array = rscaler.fit_transform(df)
        
        return array.reshape(-1,array.shape[1])
    
    def transform(self, X, *args):
        
        X = self.robust_scale_(X)
        
        return X


    def fit(self, X, *args):
        return self

# %%
class Clean_FeatureUnion(BaseEstimator, TransformerMixin):
    """Convert array from feature union into dataframe"""
    
    def __init__(self):
        pass
    
    
    def array_to_df(self,array):
        
        new_columns = list(X.columns)
        new_columns.extend(['icutype3','icutype4'])
        
        X_df = pd.DataFrame(array,columns=new_columns,index=X.index)
        X_df = X_df.rename(columns={'icutype':'icutype2'})
        
        return X_df
    
    def transform(self, union_array, *args):
        
        df = self.array_to_df(union_array)
        
        return df


    def fit(self, union_array, *args):
        return self

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <b> Variance Inflation Factor</b>
#
# </div>

# %% [markdown]
# As we can see from the correlation matrix that there are some features that are multicollinear with each other. The existence of multicolinear features may add noise to our model resulting in overfitting. Using the variance inflation factor(VIF), we will be able to estimate how much the variance of a regression coefficient of a particular feature is inflated due to multicollinearity.
# <br><br>
# The VIF ranges from 1 (1 being not correlated). We have set a threshold of 5, any features with VIF > 5 will be eliminated from the modeling.
# <br><br>
# $$VIF = \frac{1}{1 - R_{i}^{2}}$$
# where $i = x_{1},x_{2}..x_{n}$

# %%
# Variance Inflation Factor

class VIF(BaseEstimator, TransformerMixin):
    """Variance Inflation Factor"""
    
    def __init__(self,threshold=5):
        self.threshold = threshold
    
    
    def vif(self,df):
        
        vif = [variance_inflation_factor(df.iloc[:,:-4].values,i) \
               for i in range(df.iloc[:,:-4].shape[1])]
        
        vif_df = pd.DataFrame(df.iloc[:,:-4].columns,columns=['Features'])
        vif_df['VIF'] = vif    # VIF values in dataframe
        
        remove_col = list(vif_df[vif_df['VIF']>self.threshold]['Features'])   # Choose only features with VIF < 5
        selected_df = df.drop(remove_col,axis=1)
        
        return selected_df
    
    def transform(self, df, *args):
        
        selected_df = self.vif(df)
        
        return selected_df


    def fit(self, df, *args):
        return self

# %%
X = mortality.drop(['in-hospital_death','NaNs','height','sofa'],axis=1) # identify predictors 
y = mortality['in-hospital_death']

# %%
feature_union = FeatureUnion([  
    ('numerical_scaler',Numerical_Extractor()),
    ('categorical_transform',Categorical_Extractor())  ])

pipeline = Pipeline(
    
    steps=[ ('drop_data', feature_union),
           ('clean_union',Clean_FeatureUnion()),
           ('VIF',VIF())
          
          ])

X_transformed = pipeline.fit_transform(X)

# %%
# Boxplot
sns.set(rc={"figure.figsize": (15, 30)})
sns.boxplot(data=X_transformed, orient="h", palette="Set2")

# %%
# Correlation Matrix after removing features that are multi-colinear

sns.set(rc={"figure.figsize": (15, 10)})

corr = X_transformed.corr()
cmap = sns.color_palette("RdBu_r", 7)

sns.heatmap(corr,cmap=cmap)

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <span style="color:purple;font-size:13pt"><b>SOFA score as benchmark</span></b>
# <b></b>
#
#
# </div>

# %% [markdown]
# <b>Results</b>
#
# Benchmarking based on SOFA (Sequential Organ Failure Assessment) scores.
#
# The SOFA score is available under the outcome-related descriptors in our dataset. Do note that SOFA score is designed to evaluate organ dysfunction in critically ill patients and not directly to predict mortality. However, SOFA scores can be used as an estimation of mortality in the ICU based on two research papers:
#
# 1.	Vincent JL, de Mendonça A, Cantraine F, et al. Use of the SOFA score to assess the incidence of organ dysfunction/failure in intensive care units: results of a multicenter, prospective study. Working group on "sepsis-related problems" of the European Society of Intensive Care Medicine. Crit Care Med. 1998;26(11):1793-800. PMID 9824069.
# <Br><br>
# 2.	Ferreira FL, Bota DP, Bross A, et al. Serial evaluation of the SOFA score to predict outcome in critically ill patients. JAMA. 2001;286(14):1754-8. PMID 11594901.
# <br><br>
# Mortality estimated by SOFA score can be summarised in the table below:

# %% [markdown]
# <table class="dataTable dataTableCenter" style="margin-bottom: 1em;">
#             <tbody><tr class="dataRowHeader">
#                 <td><b>Maximum<br> SOFA Score</td></b>
#                 <td><b>Mortality</td></b>
#             </tr>
#             <tr class="dataRowOdd">
#                 <td>0 to 6</td>
#                 <td>&lt; 10%</td>
#             </tr>
#             <tr class="dataRowEven">
#                 <td>7 to 9</td>
#                 <td>15 - 20%</td>
#             </tr>
#             <tr class="dataRowOdd">
#                 <td>10 to 12</td>
#                 <td>40 - 50%</td>
#             </tr>
#             <tr class="dataRowEven">
#                 <td>13 to 14</td>
#                 <td>50 - 60%</td>
#             </tr>
#             <tr class="dataRowOdd">
#                 <td>15</td>
#                 <td>&gt; 80%</td>
#             </tr>
#             <tr class="dataRowEven">
#                 <td>15 to 24</td>
#                 <td>&gt; 90%</td>
#             </tr>
#         </tbody></table>

# %% [markdown]
# We will be taking mortality >= 50% (SOFA Score >= 13) as 'death' (1 in binary terms)
# <br><br>
# <i>*References: http://clincalc.com/IcuMortality/SOFA.aspx Jul 1 2017 - ClinCalc LLC</i>

# %%
sofa = mortality[['sofa']]
y_sofa = mortality['in-hospital_death']

# %%
sofa['sofa_mortality'] = sofa['sofa'].map(lambda x: 1 if x > 12 else 0)
# Out:
# /Users/joannasyeow/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sofa_precision = precision_score(y_sofa,sofa['sofa_mortality'])   # precision score
sofa_recall =  recall_score(y_sofa,sofa['sofa_mortality']) 
sofa_f1 = f1_score(y_sofa,sofa['sofa_mortality']) 

print 'SOFA Precision: ', sofa_precision
print 'SOFA Recall: ', sofa_recall
print 'SOFA F1: ',sofa_f1
# Out:
# SOFA Precision:  0.321766561514
# SOFA Recall:  0.206896551724
# SOFA F1:  0.251851851852

# %%
score_compare = pd.DataFrame(columns=['Classifier','Precision_Score','Recall_Score','F1_Score'])

# %%
sofa_score = pd.DataFrame([['Sofa',sofa_precision,sofa_recall,sofa_f1]],
                            columns=score_compare.columns)     # append scores in table

score_compare = score_compare.append(sofa_score)
score_compare
# Out:
#   Classifier  Precision_Score  Recall_Score  F1_Score
# 0       Sofa         0.321767      0.206897  0.251852

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# <span style="color:purple;font-size:13pt"><b>Model Training</span></b>
# <b></b>
#
# </div>

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.3, random_state=5,stratify=y)

# %%
# Dealing with imbalance with SMOTEEN resampling
smoteenn = SMOTEENN(random_state=2,smote=SMOTE(ratio={1:900},random_state=2))
X_train_res, y_train_res = smoteenn.fit_sample(X_train, y_train)

y_train_res.sum()/ len(y_train_res)  # Percentage of samples in the minority class
# Out:
# 0.38800904977375567

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = '1','0'
sizes = [y_train_res.sum(),len(y_train_res) - y_train_res.sum()]
colors = ['lightcoral','lightblue']
explode = (0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.legend()
plt.title('Class proportion after resampling')

plt.show()

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
# Feature Selection: <b>Variance Inflation Factor</b>
# <br>
# Resampling: <b>SMOTEENN</b>
# <br>
# Model: <b>Logistic Regression</b>
# </div>

# %%
# Fit resampled training set on Logistic Regression CV

logregcv = LogisticRegressionCV(n_jobs=-1, random_state=6,max_iter=200)
logregcv.fit(X_train_res, y_train_res)

y_pred = logregcv.predict(X_test)  # predictions on test

logregcv_precision = precision_score(y_test,y_pred)   # precision score
logregcv_recall = recall_score(y_test,y_pred)         # recall score
logregcv_f1 = f1_score(y_test,y_pred)                 # f1 score

logregcv_score = pd.DataFrame([['Logistic Regression',logregcv_precision,logregcv_recall,logregcv_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(logregcv_score)
score_compare
# Out:
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0                 Sofa         0.321767      0.206897  0.251852
# 0  Logistic Regression         0.285714      0.716216  0.408478

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
# Feature Selection: <b>Variance Inflation Factor</b>
# <br>
# Resampling: <b>SMOTEENN</b>
# <br>
# Model: <b>Decision Tree</b>
# </div>

# %%
# Fit resampled training set on Decision Tree (gridsearch on hyperparameters)

dtc_params = {
    'max_depth':[1,2,3,4],
    'max_features':[None,'log2','sqrt',2,3,4],
    'min_samples_split':[2,3,4,5,10,15,20,25,30,40,50]
}


dtc_gs = GridSearchCV(DecisionTreeClassifier(random_state=6), dtc_params, cv=3, verbose=1,scoring='f1')
dtc_gs.fit(X_train_res, y_train_res)

y_pred = dtc_gs.predict(X_test)   # predictions on test

dtc_precision = precision_score(y_test,y_pred)   # precision score
dtc_recall = recall_score(y_test,y_pred)         # recall score
dtc_f1 = f1_score(y_test,y_pred)                 # f1 score

dtc_score = pd.DataFrame([['Decision Tree',dtc_precision,dtc_recall,dtc_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(dtc_score)
score_compare
# Out:
# Fitting 3 folds for each of 264 candidates, totalling 792 fits
# [Parallel(n_jobs=1)]: Done 792 out of 792 | elapsed:    5.7s finished
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0                 Sofa         0.321767      0.206897  0.251852
# 0  Logistic Regression         0.285714      0.716216  0.408478
# 0        Decision Tree         0.306338      0.587838  0.402778

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
# Feature Selection: <b>Variance Inflation Factor</b>
# <br>
# Resampling: <b>SMOTEENN</b>
# <br>
# Model: <b>Random Forest</b>
# </div>

# %%
# Fit resampled training set on Random Forest (gridsearch on hyperparameters)

rfc_params = {
    'n_estimators':[500],
    'max_depth':[1,2,3,4],
    'max_features':['log2','sqrt',2,3,4,5],
    'min_samples_split':[2,3,4,5,10]
}


rfc_gs = GridSearchCV(RandomForestClassifier(random_state=6), \
                      rfc_params, cv=5, verbose=1,n_jobs=-1,scoring='f1')
rfc_gs.fit(X_train_res, y_train_res)

y_pred = rfc_gs.predict(X_test)  # predictions on test 

rfc_precision = precision_score(y_test,y_pred)   # precision score
rfc_recall = recall_score(y_test,y_pred)         # recall score
rfc_f1 = f1_score(y_test,y_pred)                 # f1 score

rfc_score = pd.DataFrame([['Random Forest',rfc_precision,rfc_recall,rfc_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(rfc_score)
score_compare
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   40.6s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed: 10.1min finished
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0                 Sofa         0.321767      0.206897  0.251852
# 0  Logistic Regression         0.285714      0.716216  0.408478
# 0        Decision Tree         0.306338      0.587838  0.402778
# 0        Random Forest         0.360515      0.567568  0.440945

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
# Feature Selection: <b>Variance Inflation Factor</b>
# <br>
# Resampling: <b>SMOTEENN</b>
# <br>
# Model: <b>SVM</b>
# </div>

# %%
svc_params = {
    'C':np.logspace(-3, 2, 10),
    'gamma':np.logspace(-5, 2, 10),
    'kernel':['linear']
}

svc_gs = GridSearchCV(SVC(random_state=2), svc_params, cv=3, verbose=1,n_jobs=-1)
svc_gs.fit(X_train_res, y_train_res)

y_pred = svc_gs.predict(X_test)   # predictions on test

svc_precision = precision_score(y_test,y_pred)   # precision score
svc_recall = recall_score(y_test,y_pred)         # recall score
svc_f1 = f1_score(y_test,y_pred)                 # f1 score

svc_score = pd.DataFrame([['Linear SVM',svc_precision,svc_recall,svc_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(svc_score)
score_compare
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  3.0min finished
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0                 Sofa         0.321767      0.206897  0.251852
# 0  Logistic Regression         0.285714      0.716216  0.408478
# 0        Decision Tree         0.306338      0.587838  0.402778
# 0        Random Forest         0.360515      0.567568  0.440945
# 0           Linear SVM         0.286486      0.716216  0.409266

# %%
svc_params = {
    'C':np.logspace(-3, 2, 10),
    'gamma':np.logspace(-5, 2, 10),
    'kernel':['rbf']
}

svc_gs = GridSearchCV(SVC(random_state=2), svc_params, cv=3, verbose=1,n_jobs=-1)
svc_gs.fit(X_train_res, y_train_res)

y_pred = svc_gs.predict(X_test)   # predictions on test

svc_precision = precision_score(y_test,y_pred)   # precision score
svc_recall = recall_score(y_test,y_pred)         # recall score
svc_f1 = f1_score(y_test,y_pred)                 # f1 score

svc_score = pd.DataFrame([['RBF SVM',svc_precision,svc_recall,svc_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(svc_score)
score_compare
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:   24.7s finished
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0                 Sofa         0.321767      0.206897  0.251852
# 0  Logistic Regression         0.285714      0.716216  0.408478
# 0        Decision Tree         0.306338      0.587838  0.402778
# 0        Random Forest         0.360515      0.567568  0.440945
# 0           Linear SVM         0.286486      0.716216  0.409266
# 0              RBF SVM         0.325444      0.371622  0.347003

# %% [markdown]
# To reduce complexity, we used Linear Discriminant Analysis (LDA) to reduce feature dimension. LDA finds a low-dimensional space such that when X is projected, the classes are well-separated at its best. However, it is essential to note that LDA assumes normality in the dataset. This assumption is violated in the case of our dataset.

# %%
X = mortality.drop(['in-hospital_death','NaNs','height','sofa'],axis=1) # identify predictors 
y = mortality['in-hospital_death']

# %%
feature_union = FeatureUnion([  
    ('numerical_scaler',Numerical_Extractor()),
    ('categorical_transform',Categorical_Extractor())  ])

pipeline = Pipeline(
    
    steps=[ ('drop_data', feature_union),
           ('clean_union',Clean_FeatureUnion()),
           ('VIF',VIF()),
           ('lda',LinearDiscriminantAnalysis())
          
          ])

X_transformed = pipeline.fit_transform(X,y)

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.3, random_state=5,stratify=y)

# SMOTEEN Resampling
smoteenn = SMOTEENN(random_state=2,smote=SMOTE(ratio={1:900},random_state=2))
X_train_res, y_train_res = smoteenn.fit_sample(X_train, y_train)

y_train_res.sum()/ len(y_train_res)
# Out:
# 0.18773656320968962

# %%
score_compare = pd.DataFrame(columns=['Classifier','Precision_Score','Recall_Score','F1_Score'])

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# Feature Selection: <b>VIF</b>
# <br>
# Dimentionality: <b>Linear Discriminant Analysis</b>
# <br>
# Resampling: <b>SMOTEENN</b>
# <br>
# Model: <b>Logistic Regression</b>
# </div>

# %%
# Fit resampled training set on Logistic Regression CV

logregcv = LogisticRegressionCV(n_jobs=-1, random_state=6,max_iter=200)
logregcv.fit(X_train_res, y_train_res)

y_pred = logregcv.predict(X_test)  # predictions on test

logregcv_precision = precision_score(y_test,y_pred)   # precision score
logregcv_recall = recall_score(y_test,y_pred)         # recall score
logregcv_f1 = f1_score(y_test,y_pred)                 # f1 score

dtc_score = pd.DataFrame([['Logistic Regression',logregcv_precision,logregcv_recall,logregcv_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(logregcv_score)
score_compare
# Out:
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0  Logistic Regression         0.285714      0.716216  0.408478

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# Feature Selection: <b>VIF</b>
# <br>
# Dimentionality: <b>Linear Discriminant Analysis</b>
# <br>
# Resampling: <b>SMOTEENN</b>
# <br>
# Model: <b>Decision Tree</b>
# </div>

# %%
# Fit resampled training set on Decision Tree (gridsearch on hyperparameters)

dtc_params = {
    'max_depth':[1,2,3,4],
    'min_samples_split':[2,3,4,5,10,15,20,25,30,40,50]
}


dtc_gs = GridSearchCV(DecisionTreeClassifier(random_state=6), dtc_params, cv=3, verbose=1,scoring='f1')
dtc_gs.fit(X_train_res, y_train_res)

y_pred = dtc_gs.predict(X_test)   # predictions on test

dtc_precision = precision_score(y_test,y_pred)   # precision score
dtc_recall = recall_score(y_test,y_pred)         # recall score
dtc_f1 = f1_score(y_test,y_pred)                 # f1 score

dtc_score = pd.DataFrame([['Decision Tree',dtc_precision,dtc_recall,dtc_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(dtc_score)
score_compare
# Out:
# Fitting 3 folds for each of 44 candidates, totalling 132 fits
# [Parallel(n_jobs=1)]: Done 132 out of 132 | elapsed:    0.7s finished
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0  Logistic Regression         0.285714      0.716216  0.408478
# 0        Decision Tree         0.415584      0.432432  0.423841

# %% [markdown]
# <div style="width:900px;background:#F9EECF;border:1px solid black;text-align:left;padding:20px;">
#
# <p>
#
# Feature Selection: <b>VIF</b>
# <br>
# Dimentionality: <b>Linear Discriminant Analysis</b>
# <br>
# Resampling: <b>SMOTEENN</b>
# <br>
# Model: <b>SVM</b>
# </div>

# %%
svc_params = {
    'C':np.logspace(-3, 2, 10),
    'gamma':np.logspace(-5, 2, 10),
    'kernel':['linear']
}

svc_gs = GridSearchCV(SVC(random_state=2), svc_params, cv=3, verbose=1,n_jobs=-1)
svc_gs.fit(X_train_res, y_train_res)

y_pred = svc_gs.predict(X_test)   # predictions on test

svc_precision = precision_score(y_test,y_pred)   # precision score
svc_recall = recall_score(y_test,y_pred)         # recall score
svc_f1 = f1_score(y_test,y_pred)                 # f1 score

svc_score = pd.DataFrame([['Linear SVM',svc_precision,svc_recall,svc_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(svc_score)
score_compare
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    1.7s finished
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0  Logistic Regression         0.285714      0.716216  0.408478
# 0        Decision Tree         0.415584      0.432432  0.423841
# 0           Linear SVM         0.452229      0.479730  0.465574

# %%
svc_params = {
    'C':np.logspace(-3, 2, 10),
    'gamma':np.logspace(-5, 2, 10),
    'kernel':['rbf']
}

svc_gs = GridSearchCV(SVC(random_state=2), svc_params, cv=3, verbose=1,n_jobs=-1)
svc_gs.fit(X_train_res, y_train_res)

y_pred = svc_gs.predict(X_test)   # predictions on test

svc_precision = precision_score(y_test,y_pred)   # precision score
svc_recall = recall_score(y_test,y_pred)         # recall score
svc_f1 = f1_score(y_test,y_pred)                 # f1 score

svc_score = pd.DataFrame([['RBF SVM',svc_precision,svc_recall,svc_f1]],
                            columns=score_compare.columns)  # append scores in table

score_compare = score_compare.append(svc_score)
score_compare
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    2.3s finished
#             Classifier  Precision_Score  Recall_Score  F1_Score
# 0  Logistic Regression         0.285714      0.716216  0.408478
# 0        Decision Tree         0.415584      0.432432  0.423841
# 0           Linear SVM         0.452229      0.479730  0.465574
# 0              RBF SVM         0.322917      0.418919  0.364706
